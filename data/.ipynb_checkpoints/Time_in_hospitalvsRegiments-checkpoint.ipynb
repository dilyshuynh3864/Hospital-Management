# %%
import pandas as pd
import numpy as np

# !pip install mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# !pip install scipy
import scipy.stats as stats

# !pip install statsmodels
from statsmodels.stats.multicomp import pairwise_tukeyhsd

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /opt/anaconda3/lib/python3.13/pty.py:95: DeprecationWarning: This process (pid=82897) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Requirement already satisfied: mlxtend in /opt/anaconda3/lib/python3.13/site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in /opt/anaconda3/lib/python3.13/site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in /opt/anaconda3/lib/python3.13/site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in /opt/anaconda3/lib/python3.13/site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /opt/anaconda3/lib/python3.13/site-packages (from mlxtend) (3.10.9)
# Requirement already satisfied: joblib>=1.5.2 in /opt/anaconda3/lib/python3.13/site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# /opt/anaconda3/lib/python3.13/pty.py:95: DeprecationWarning: This process (pid=82897) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.13/site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /opt/anaconda3/lib/python3.13/site-packages (from scipy) (2.3.5)
# /opt/anaconda3/lib/python3.13/pty.py:95: DeprecationWarning: This process (pid=82897) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.13/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/anaconda3/lib/python3.13/site-packages (from statsmodels) (2.3.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/lib/python3.13/site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/anaconda3/lib/python3.13/site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.13/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.13/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
df = pd.read_csv('processed.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76704 entries, 0 to 76703
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   encounter_id              76704 non-null  int64
#  1   patient_nbr               76704 non-null  int64
#  2   race                      74859 non-null  object
#  3   gender                    76704 non-null  object
#  4   age                       76704 non-null  object
#  5   admission_type_id         76704 non-null  int64
#  6   discharge_disposition_id  76704 non-null  int64
#  7   admission_source_id       76704 non-null  int64
#  8   time_in_hospital          76704 non-null  int64
#  9   medical_specialty         39648 non-null  object
#  10  num_lab_procedures        76704 non-null  int64
#  11  num_procedures            76704 non-null  int64
#  12  num_medications           76704 non-null  int64
#  13  number_outpatient         76704 non-null  int64
#  14  number_emergency          76704 non-null  int64
#  15  number_inpatient          76704 non-null  int64
#  16  diag_1                    76704 non-null  object
#  17  diag_2                    76403 non-null  object
#  18  diag_3                    75576 non-null  object
#  19  number_diagnoses          76704 non-null  int64
#  20  max_glu_serum             3800 non-null   object
#  21  A1Cresult                 14081 non-null  object
#  22  metformin                 76704 non-null  object
#  23  repaglinide               76704 non-null  object
#  24  nateglinide               76704 non-null  object
#  25  chlorpropamide            76704 non-null  object
#  26  glimepiride               76704 non-null  object
#  27  acetohexamide             76704 non-null  object
#  28  glipizide                 76704 non-null  object
#  29  glyburide                 76704 non-null  object
#  30  tolbutamide               76704 non-null  object
#  31  pioglitazone              76704 non-null  object
#  32  rosiglitazone             76704 non-null  object
#  33  acarbose                  76704 non-null  object
#  34  miglitol                  76704 non-null  object
#  35  troglitazone              76704 non-null  object
#  36  tolazamide                76704 non-null  object
#  37  examide                   76704 non-null  object
#  38  citoglipton               76704 non-null  object
#  39  insulin                   76704 non-null  object
#  40  glyburide-metformin       76704 non-null  object
#  41  glipizide-metformin       76704 non-null  object
#  42  glimepiride-pioglitazone  76704 non-null  object
#  43  metformin-rosiglitazone   76704 non-null  object
#  44  metformin-pioglitazone    76704 non-null  object
#  45  change                    76704 non-null  object
#  46  diabetesMed               76704 non-null  object
#  47  readmitted                76704 non-null  object
# dtypes: int64(13), object(35)
# memory usage: 28.1+ MB

# %%
med_cols = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 
              'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol','troglitazone', 
              'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 
              'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone']

for med in med_cols:
    count = (df[med] != 'No').sum()
    print (med, count)
# Out:
# metformin 19839
# repaglinide 1518
# nateglinide 688
# chlorpropamide 85
# glimepiride 5120
# acetohexamide 1
# glipizide 12528
# glyburide 10521
# tolbutamide 21
# pioglitazone 7253
# rosiglitazone 6301
# acarbose 305
# miglitol 38
# troglitazone 3
# tolazamide 39
# examide 0
# citoglipton 0
# insulin 52955
# glyburide-metformin 698
# glipizide-metformin 13
# glimepiride-pioglitazone 1
# metformin-rosiglitazone 2
# metformin-pioglitazone 1

# %%
core_meds = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 
             'pioglitazone', 'rosiglitazone', 'acarbose', 'insulin', 'glyburide-metformin', 'glipizide-metformin']

def get_active_meds(row):
    active_meds = [meds for meds in core_meds if row[meds] in ['Up', 'Down', 'Steady']]
    if len(active_meds) > 0:
        return active_meds
    else:
        return ['No_Diabetes_Med']

df['medication_list'] = df.apply(get_active_meds, axis = 1)
df['medication_list'].head()
# Out:
# 0               [insulin]
# 1             [glipizide]
# 2               [insulin]
# 3    [glipizide, insulin]
# 4               [insulin]
# Name: medication_list, dtype: object

# %%
te = TransactionEncoder()
te_array = te.fit(df['medication_list']).transform(df['medication_list'])
df_onehot = pd.DataFrame(te_array, columns = te.columns_)

df_onehot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76704 entries, 0 to 76703
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   No_Diabetes_Med      76704 non-null  bool
#  1   acarbose             76704 non-null  bool
#  2   chlorpropamide       76704 non-null  bool
#  3   glimepiride          76704 non-null  bool
#  4   glipizide            76704 non-null  bool
#  5   glipizide-metformin  76704 non-null  bool
#  6   glyburide            76704 non-null  bool
#  7   glyburide-metformin  76704 non-null  bool
#  8   insulin              76704 non-null  bool
#  9   metformin            76704 non-null  bool
#  10  nateglinide          76704 non-null  bool
#  11  pioglitazone         76704 non-null  bool
#  12  repaglinide          76704 non-null  bool
#  13  rosiglitazone        76704 non-null  bool
# dtypes: bool(14)
# memory usage: 1.0 MB

# %%
for s in [0.02, 0.01, 0.005, 0.002, 0.001]:
    fi = apriori(df_onehot, min_support = s, use_colnames = True)
    print(s, len(fi))
# Out:
# 0.02 19
# 0.01 29
# 0.005 42
# 0.002 57
# 0.001 75

# %%
frequent_itemsets = apriori(df_onehot, min_support = 0.005, use_colnames = True)
frequent_itemsets
# Out:
#      support                               itemsets
# 0   0.066750                          (glimepiride)
# 1   0.163329                            (glipizide)
# 2   0.137164                            (glyburide)
# 3   0.009100                  (glyburide-metformin)
# 4   0.690381                              (insulin)
# 5   0.258644                            (metformin)
# 6   0.008970                          (nateglinide)
# 7   0.094558                         (pioglitazone)
# 8   0.019790                          (repaglinide)
# 9   0.082147                        (rosiglitazone)
# 10  0.036556                 (glimepiride, insulin)
# 11  0.017991               (glimepiride, metformin)
# 12  0.008200            (pioglitazone, glimepiride)
# 13  0.006936           (glimepiride, rosiglitazone)
# 14  0.079422                   (glipizide, insulin)
# 15  0.045839                 (glipizide, metformin)
# 16  0.017287              (pioglitazone, glipizide)
# 17  0.014641             (glipizide, rosiglitazone)
# 18  0.057259                   (insulin, glyburide)
# 19  0.049502                 (glyburide, metformin)
# 20  0.012477              (pioglitazone, glyburide)
# 21  0.012098             (glyburide, rosiglitazone)
# 22  0.005293         (insulin, glyburide-metformin)
# 23  0.129472                   (insulin, metformin)
# 24  0.051210                (pioglitazone, insulin)
# 25  0.011225                 (insulin, repaglinide)
# 26  0.044509               (insulin, rosiglitazone)
# 27  0.026335              (pioglitazone, metformin)
# 28  0.028447             (rosiglitazone, metformin)
# 29  0.010443      (glimepiride, insulin, metformin)
# 30  0.023715        (glipizide, insulin, metformin)
# 31  0.008591     (pioglitazone, insulin, glipizide)
# 32  0.007535    (glipizide, insulin, rosiglitazone)
# 33  0.005423   (pioglitazone, glipizide, metformin)
# 34  0.005515  (glipizide, rosiglitazone, metformin)
# 35  0.021642        (insulin, glyburide, metformin)
# 36  0.005958     (pioglitazone, insulin, glyburide)
# 37  0.005684    (insulin, glyburide, rosiglitazone)
# 38  0.005137   (pioglitazone, glyburide, metformin)
# 39  0.005541  (glyburide, rosiglitazone, metformin)
# 40  0.014667     (pioglitazone, insulin, metformin)
# 41  0.015280    (insulin, rosiglitazone, metformin)

# %%
rules = association_rules(frequent_itemsets, metric = 'support', min_threshold = 0)
rules
# Out:
#                     antecedents                 consequents  \
# 0                 (glimepiride)                   (insulin)
# 1                     (insulin)               (glimepiride)
# 2                 (glimepiride)                 (metformin)
# 3                   (metformin)               (glimepiride)
# 4                (pioglitazone)               (glimepiride)
# ..                          ...                         ...
# 111        (insulin, metformin)             (rosiglitazone)
# 112  (rosiglitazone, metformin)                   (insulin)
# 113                   (insulin)  (rosiglitazone, metformin)
# 114             (rosiglitazone)        (insulin, metformin)
# 115                 (metformin)    (insulin, rosiglitazone)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.066750            0.690381  0.036556    0.547656  0.793266
# 1              0.690381            0.066750  0.036556    0.052951  0.793266
# 2              0.066750            0.258644  0.017991    0.269531  1.042095
# 3              0.258644            0.066750  0.017991    0.069560  1.042095
# 4              0.094558            0.066750  0.008200    0.086723  1.299215
# ..                  ...                 ...       ...         ...       ...
# 111            0.129472            0.082147  0.015280    0.118014  1.436624
# 112            0.028447            0.690381  0.015280    0.537122  0.778008
# 113            0.690381            0.028447  0.015280    0.022132  0.778008
# 114            0.082147            0.129472  0.015280    0.186002  1.436624
# 115            0.258644            0.044509  0.015280    0.059076  1.327279
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                 1.0 -0.009527    0.684477      -0.218292  0.050732
# 1                 1.0 -0.009527    0.985429      -0.457028  0.050732
# 2                 1.0  0.000727    1.014905       0.043284  0.058527
# 3                 1.0  0.000727    1.003020       0.054488  0.058527
# 4                 1.0  0.001889    1.021869       0.254356  0.053559
# ..                ...       ...         ...            ...       ...
# 111               1.0  0.004644    1.040667       0.349126  0.077822
# 112               1.0 -0.004360    0.668899      -0.227017  0.021718
# 113               1.0 -0.004360    0.993542      -0.479591  0.021718
# 114               1.0  0.004644    1.069448       0.331125  0.077822
# 115               1.0  0.003768    1.015481       0.332605  0.053077
#
#      certainty  kulczynski
# 0    -0.460970    0.300303
# 1    -0.014786    0.300303
# 2     0.014686    0.169546
# 3     0.003011    0.169546
# 4     0.021401    0.104787
# ..         ...         ...
# 111   0.039077    0.152008
# 112  -0.494994    0.279627
# 113  -0.006500    0.279627
# 114   0.064938    0.152008
# 115   0.015245    0.201184
#
# [116 rows x 14 columns]

# %%
rules = rules[(rules['lift'] > 1)].sort_values(by = 'confidence', ascending = False)
rules
# Out:
#                     antecedents                 consequents  \
# 98   (glyburide, rosiglitazone)                 (metformin)
# 92    (pioglitazone, glyburide)                 (metformin)
# 74         (insulin, glyburide)                 (metformin)
# 68   (glipizide, rosiglitazone)                 (metformin)
# 18                  (glyburide)                 (metformin)
# ..                          ...                         ...
# 66                  (glipizide)   (pioglitazone, metformin)
# 103                 (metformin)  (glyburide, rosiglitazone)
# 73                  (metformin)  (glipizide, rosiglitazone)
# 67                  (metformin)   (pioglitazone, glipizide)
# 97                  (metformin)   (pioglitazone, glyburide)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 98             0.012098            0.258644  0.005541    0.457974  1.770676
# 92             0.012477            0.258644  0.005137    0.411703  1.591778
# 74             0.057259            0.258644  0.021642    0.377960  1.461316
# 68             0.014641            0.258644  0.005515    0.376670  1.456327
# 18             0.137164            0.258644  0.049502    0.360897  1.395346
# ..                  ...                 ...       ...         ...       ...
# 66             0.163329            0.026335  0.005423    0.033206  1.260893
# 103            0.258644            0.012098  0.005541    0.021422  1.770676
# 73             0.258644            0.014641  0.005515    0.021322  1.456327
# 67             0.258644            0.017287  0.005423    0.020969  1.212964
# 97             0.258644            0.012477  0.005137    0.019860  1.591778
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 98                1.0  0.002412    1.367751       0.440574  0.020893
# 92                1.0  0.001910    1.260174       0.376469  0.019312
# 74                1.0  0.006832    1.191815       0.334859  0.073546
# 68                1.0  0.001728    1.189347       0.317997  0.020595
# 18                1.0  0.014025    1.159996       0.328372  0.142943
# ..                ...       ...         ...            ...       ...
# 66                1.0  0.001122    1.007107       0.247303  0.029437
# 103               1.0  0.002412    1.009528       0.587092  0.020893
# 73                1.0  0.001728    1.006826       0.422659  0.020595
# 67                1.0  0.000952    1.003760       0.236827  0.020049
# 97                1.0  0.001910    1.007533       0.501475  0.019312
#
#      certainty  kulczynski
# 98    0.268873    0.239698
# 92    0.206459    0.215782
# 74    0.160943    0.230817
# 68    0.159203    0.198996
# 18    0.137928    0.276144
# ..         ...         ...
# 66    0.007056    0.119573
# 103   0.009438    0.239698
# 73    0.006780    0.198996
# 67    0.003746    0.167347
# 97    0.007477    0.215782
#
# [76 rows x 14 columns]

# %%
df['readmitted_30days'] = np.where(df['readmitted'] == '<30', 'True', 'False')
df
# Out:
#        encounter_id  patient_nbr             race  gender      age  \
# 0            149190     55629189        Caucasian  Female  [10-20)
# 1             64410     86047875  AfricanAmerican  Female  [20-30)
# 2            500364     82442376        Caucasian    Male  [30-40)
# 3             16680     42519267        Caucasian    Male  [40-50)
# 4             35754     82637451        Caucasian    Male  [50-60)
# ...             ...          ...              ...     ...      ...
# 76699     443847176     50375628  AfricanAmerican  Female  [60-70)
# 76700     443847548    100162476  AfricanAmerican    Male  [70-80)
# 76701     443847782     74694222  AfricanAmerican  Female  [80-90)
# 76702     443854148     41088789        Caucasian    Male  [70-80)
# 76703     443857166     31693671        Caucasian  Female  [80-90)
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                      1                         1                    7
# 1                      1                         1                    7
# 2                      1                         1                    7
# 3                      1                         1                    7
# 4                      2                         1                    2
# ...                  ...                       ...                  ...
# 76699                  1                         1                    7
# 76700                  1                         3                    7
# 76701                  1                         4                    5
# 76702                  1                         1                    7
# 76703                  2                         3                    7
#
#        time_in_hospital medical_specialty  ...  glyburide-metformin  \
# 0                     3               NaN  ...                   No
# 1                     2               NaN  ...                   No
# 2                     2               NaN  ...                   No
# 3                     1               NaN  ...                   No
# 4                     3               NaN  ...                   No
# ...                 ...               ...  ...                  ...
# 76699                 6               NaN  ...                   No
# 76700                 3               NaN  ...                   No
# 76701                 5               NaN  ...                   No
# 76702                 1               NaN  ...                   No
# 76703                10   Surgery-General  ...                   No
#
#        glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                       No                        No                       No
# 1                       No                        No                       No
# 2                       No                        No                       No
# 3                       No                        No                       No
# 4                       No                        No                       No
# ...                    ...                       ...                      ...
# 76699                   No                        No                       No
# 76700                   No                        No                       No
# 76701                   No                        No                       No
# 76702                   No                        No                       No
# 76703                   No                        No                       No
#
#        metformin-pioglitazone  change diabetesMed readmitted  \
# 0                          No      Ch         Yes        >30
# 1                          No      No         Yes         NO
# 2                          No      Ch         Yes         NO
# 3                          No      Ch         Yes         NO
# 4                          No      No         Yes        >30
# ...                       ...     ...         ...        ...
# 76699                      No      Ch         Yes        >30
# 76700                      No      Ch         Yes        >30
# 76701                      No      No         Yes         NO
# 76702                      No      Ch         Yes         NO
# 76703                      No      Ch         Yes         NO
#
#                           medication_list  readmitted_30days
# 0                               [insulin]              False
# 1                             [glipizide]              False
# 2                               [insulin]              False
# 3                    [glipizide, insulin]              False
# 4                               [insulin]              False
# ...                                   ...                ...
# 76699            [rosiglitazone, insulin]              False
# 76700                [metformin, insulin]              False
# 76701                           [insulin]              False
# 76702                [metformin, insulin]              False
# 76703  [glipizide, pioglitazone, insulin]              False
#
# [76704 rows x 50 columns]

# %%
df['regiment'] = df['medication_list'].apply(lambda x: ('+').join(sorted(x)))
df
# Out:
#        encounter_id  patient_nbr             race  gender      age  \
# 0            149190     55629189        Caucasian  Female  [10-20)
# 1             64410     86047875  AfricanAmerican  Female  [20-30)
# 2            500364     82442376        Caucasian    Male  [30-40)
# 3             16680     42519267        Caucasian    Male  [40-50)
# 4             35754     82637451        Caucasian    Male  [50-60)
# ...             ...          ...              ...     ...      ...
# 76699     443847176     50375628  AfricanAmerican  Female  [60-70)
# 76700     443847548    100162476  AfricanAmerican    Male  [70-80)
# 76701     443847782     74694222  AfricanAmerican  Female  [80-90)
# 76702     443854148     41088789        Caucasian    Male  [70-80)
# 76703     443857166     31693671        Caucasian  Female  [80-90)
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                      1                         1                    7
# 1                      1                         1                    7
# 2                      1                         1                    7
# 3                      1                         1                    7
# 4                      2                         1                    2
# ...                  ...                       ...                  ...
# 76699                  1                         1                    7
# 76700                  1                         3                    7
# 76701                  1                         4                    5
# 76702                  1                         1                    7
# 76703                  2                         3                    7
#
#        time_in_hospital medical_specialty  ...  glipizide-metformin  \
# 0                     3               NaN  ...                   No
# 1                     2               NaN  ...                   No
# 2                     2               NaN  ...                   No
# 3                     1               NaN  ...                   No
# 4                     3               NaN  ...                   No
# ...                 ...               ...  ...                  ...
# 76699                 6               NaN  ...                   No
# 76700                 3               NaN  ...                   No
# 76701                 5               NaN  ...                   No
# 76702                 1               NaN  ...                   No
# 76703                10   Surgery-General  ...                   No
#
#        glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                            No                       No
# 1                            No                       No
# 2                            No                       No
# 3                            No                       No
# 4                            No                       No
# ...                         ...                      ...
# 76699                        No                       No
# 76700                        No                       No
# 76701                        No                       No
# 76702                        No                       No
# 76703                        No                       No
#
#        metformin-pioglitazone  change  diabetesMed readmitted  \
# 0                          No      Ch          Yes        >30
# 1                          No      No          Yes         NO
# 2                          No      Ch          Yes         NO
# 3                          No      Ch          Yes         NO
# 4                          No      No          Yes        >30
# ...                       ...     ...          ...        ...
# 76699                      No      Ch          Yes        >30
# 76700                      No      Ch          Yes        >30
# 76701                      No      No          Yes         NO
# 76702                      No      Ch          Yes         NO
# 76703                      No      Ch          Yes         NO
#
#                           medication_list readmitted_30days  \
# 0                               [insulin]             False
# 1                             [glipizide]             False
# 2                               [insulin]             False
# 3                    [glipizide, insulin]             False
# 4                               [insulin]             False
# ...                                   ...               ...
# 76699            [rosiglitazone, insulin]             False
# 76700                [metformin, insulin]             False
# 76701                           [insulin]             False
# 76702                [metformin, insulin]             False
# 76703  [glipizide, pioglitazone, insulin]             False
#
#                              regiment
# 0                             insulin
# 1                           glipizide
# 2                             insulin
# 3                   glipizide+insulin
# 4                             insulin
# ...                               ...
# 76699           insulin+rosiglitazone
# 76700               insulin+metformin
# 76701                         insulin
# 76702               insulin+metformin
# 76703  glipizide+insulin+pioglitazone
#
# [76704 rows x 51 columns]

# %%
df['regiment'].value_counts()
# Out:
# regiment
# insulin                                      29884
# metformin                                     4451
# insulin+metformin                             4306
# glipizide                                     3816
# glyburide                                     3333
#                                              ...
# glimepiride+glipizide+glyburide+insulin          1
# glyburide+nateglinide+rosiglitazone              1
# acarbose+glipizide+glyburide+insulin             1
# glimepiride+glipizide+insulin+nateglinide        1
# glimepiride+glipizide+glyburide+metformin        1
# Name: count, Length: 298, dtype: int64

# %%
top_regiments = df['regiment'].value_counts().head(10).index
top_regiments
# Out:
# Index(['insulin', 'metformin', 'insulin+metformin', 'glipizide', 'glyburide',
#        'glipizide+insulin', 'glyburide+insulin', 'insulin+pioglitazone',
#        'glyburide+metformin', 'glimepiride+insulin'],
#       dtype='object', name='regiment')

# %%
groups = []
for r in top_regiments:
    time = df[df['regiment'] == r]['time_in_hospital'].values
    groups.append(time)

f_stats, p_value = stats.f_oneway(*groups)
print(f"ANOVA Result: F-Statistic = {f_stats}, p-value = {p_value}")
# Out:
# ANOVA Result: F-Statistic = 47.70524555548092, p-value = 1.6412804745525437e-86

# %% [markdown]
# A one-way ANOVA revealed a statistically significant difference in mean hospital stay across medication regimens, F = 47.71, p < 0.001. This suggests that hospitalization duration varies significantly among different treatment regimens.

# %%
df_top_regiment = df[df['regiment'].isin(top_regiments)]
df_top_regiment
# Out:
#        encounter_id  patient_nbr             race  gender      age  \
# 0            149190     55629189        Caucasian  Female  [10-20)
# 1             64410     86047875  AfricanAmerican  Female  [20-30)
# 2            500364     82442376        Caucasian    Male  [30-40)
# 3             16680     42519267        Caucasian    Male  [40-50)
# 4             35754     82637451        Caucasian    Male  [50-60)
# ...             ...          ...              ...     ...      ...
# 76697     443842340    120975314        Caucasian  Female  [80-90)
# 76698     443842778     86472243        Caucasian    Male  [80-90)
# 76700     443847548    100162476  AfricanAmerican    Male  [70-80)
# 76701     443847782     74694222  AfricanAmerican  Female  [80-90)
# 76702     443854148     41088789        Caucasian    Male  [70-80)
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                      1                         1                    7
# 1                      1                         1                    7
# 2                      1                         1                    7
# 3                      1                         1                    7
# 4                      2                         1                    2
# ...                  ...                       ...                  ...
# 76697                  1                         1                    7
# 76698                  1                         1                    7
# 76700                  1                         3                    7
# 76701                  1                         4                    5
# 76702                  1                         1                    7
#
#        time_in_hospital medical_specialty  ...  glipizide-metformin  \
# 0                     3               NaN  ...                   No
# 1                     2               NaN  ...                   No
# 2                     2               NaN  ...                   No
# 3                     1               NaN  ...                   No
# 4                     3               NaN  ...                   No
# ...                 ...               ...  ...                  ...
# 76697                 5               NaN  ...                   No
# 76698                 1               NaN  ...                   No
# 76700                 3               NaN  ...                   No
# 76701                 5               NaN  ...                   No
# 76702                 1               NaN  ...                   No
#
#        glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                            No                       No
# 1                            No                       No
# 2                            No                       No
# 3                            No                       No
# 4                            No                       No
# ...                         ...                      ...
# 76697                        No                       No
# 76698                        No                       No
# 76700                        No                       No
# 76701                        No                       No
# 76702                        No                       No
#
#        metformin-pioglitazone  change  diabetesMed readmitted  \
# 0                          No      Ch          Yes        >30
# 1                          No      No          Yes         NO
# 2                          No      Ch          Yes         NO
# 3                          No      Ch          Yes         NO
# 4                          No      No          Yes        >30
# ...                       ...     ...          ...        ...
# 76697                      No      Ch          Yes         NO
# 76698                      No      Ch          Yes         NO
# 76700                      No      Ch          Yes        >30
# 76701                      No      No          Yes         NO
# 76702                      No      Ch          Yes         NO
#
#             medication_list readmitted_30days           regiment
# 0                 [insulin]             False            insulin
# 1               [glipizide]             False          glipizide
# 2                 [insulin]             False            insulin
# 3      [glipizide, insulin]             False  glipizide+insulin
# 4                 [insulin]             False            insulin
# ...                     ...               ...                ...
# 76697             [insulin]             False            insulin
# 76698             [insulin]             False            insulin
# 76700  [metformin, insulin]             False  insulin+metformin
# 76701             [insulin]             False            insulin
# 76702  [metformin, insulin]             False  insulin+metformin
#
# [56016 rows x 51 columns]

# %%
tukey = pairwise_tukeyhsd(
    endog = df_top_regiment['time_in_hospital'],
    groups = df_top_regiment['regiment'],
    alpha = 0.05
)
print(tukey.summary())
# Out:
#               Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================================
#        group1               group2        meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------------------
#  glimepiride+insulin            glipizide  -0.8256    0.0 -1.1171 -0.5341   True
#  glimepiride+insulin    glipizide+insulin  -0.1182 0.9632  -0.416  0.1797  False
#  glimepiride+insulin            glyburide  -0.5614    0.0 -0.8586 -0.2642   True
#  glimepiride+insulin    glyburide+insulin  -0.0633 0.9998 -0.3853  0.2587  False
#  glimepiride+insulin  glyburide+metformin  -0.7377    0.0 -1.0773 -0.3981   True
#  glimepiride+insulin              insulin  -0.4364    0.0 -0.6906 -0.1823   True
#  glimepiride+insulin    insulin+metformin  -0.4079 0.0003 -0.6948  -0.121   True
#  glimepiride+insulin insulin+pioglitazone  -0.2349 0.4523 -0.5718   0.102  False
#  glimepiride+insulin            metformin  -1.1369    0.0 -1.4226 -0.8511   True
#            glipizide    glipizide+insulin   0.7074    0.0  0.4828  0.9321   True
#            glipizide            glyburide   0.2642 0.0072  0.0404   0.488   True
#            glipizide    glyburide+insulin   0.7623    0.0  0.5065   1.018   True
#            glipizide  glyburide+metformin   0.0879 0.9923 -0.1897  0.3654  False
#            glipizide              insulin   0.3892    0.0  0.2269  0.5514   True
#            glipizide    insulin+metformin   0.4177    0.0  0.2078  0.6275   True
#            glipizide insulin+pioglitazone   0.5906    0.0  0.3163  0.8649   True
#            glipizide            metformin  -0.3113 0.0001 -0.5195  -0.103   True
#    glipizide+insulin            glyburide  -0.4432    0.0 -0.6753 -0.2112   True
#    glipizide+insulin    glyburide+insulin   0.0549 0.9997 -0.2081  0.3178  False
#    glipizide+insulin  glyburide+metformin  -0.6196    0.0 -0.9039 -0.3353   True
#    glipizide+insulin              insulin  -0.3183    0.0 -0.4918 -0.1447   True
#    glipizide+insulin    insulin+metformin  -0.2897 0.0011 -0.5084 -0.0711   True
#    glipizide+insulin insulin+pioglitazone  -0.1168 0.9507 -0.3979  0.1643  False
#    glipizide+insulin            metformin  -1.0187    0.0 -1.2358 -0.8016   True
#            glyburide    glyburide+insulin   0.4981    0.0  0.2358  0.7603   True
#            glyburide  glyburide+metformin  -0.1763 0.6224 -0.4599  0.1073  False
#            glyburide              insulin    0.125 0.3929 -0.0474  0.2973  False
#            glyburide    insulin+metformin   0.1535 0.4359 -0.0643  0.3713  False
#            glyburide insulin+pioglitazone   0.3265 0.0087  0.0461  0.6068   True
#            glyburide            metformin  -0.5755    0.0 -0.7917 -0.3593   True
#    glyburide+insulin  glyburide+metformin  -0.6744    0.0 -0.9838  -0.365   True
#    glyburide+insulin              insulin  -0.3731    0.0 -0.5853 -0.1609   True
#    glyburide+insulin    insulin+metformin  -0.3446 0.0006 -0.5951 -0.0941   True
#    glyburide+insulin insulin+pioglitazone  -0.1716 0.7533 -0.4781  0.1349  False
#    glyburide+insulin            metformin  -1.0736    0.0 -1.3227 -0.8244   True
#  glyburide+metformin              insulin   0.3013 0.0025  0.0632  0.5394   True
#  glyburide+metformin    insulin+metformin   0.3298 0.0051  0.0571  0.6026   True
#  glyburide+metformin insulin+pioglitazone   0.5028    0.0  0.1778  0.8277   True
#  glyburide+metformin            metformin  -0.3991 0.0001 -0.6707 -0.1276   True
#              insulin    insulin+metformin   0.0285 0.9999 -0.1253  0.1824  False
#              insulin insulin+pioglitazone   0.2015  0.165 -0.0328  0.4357  False
#              insulin            metformin  -0.7004    0.0 -0.8521 -0.5488   True
#    insulin+metformin insulin+pioglitazone    0.173 0.5768 -0.0965  0.4424  False
#    insulin+metformin            metformin   -0.729    0.0 -0.9307 -0.5272   True
# insulin+pioglitazone            metformin  -0.9019    0.0 -1.1701 -0.6338   True
# --------------------------------------------------------------------------------

# %% [markdown]
# # The Tukey HSD post-hoc test reveals three clinically meaningful patterns in treatment regimens and their impact on hospital length of stay ($LOS$).
#
# ### 1. Metformin Monotherapy: The Best Performing Regimen
#
# Across all pairwise comparisons where **metformin** appears as `group2`, a highly consistent pattern is observed:
# * **Mean differences** are consistently negative and large (ranging from $-0.31$ to $-1.14$ days).
# * **Statistical Significance:** All comparisons are statistically significant (`reject = True`).
#
# #### Clinical Interpretation
# Patients treated with metformin monotherapy experience **significantly shorter hospital stays** compared to all combination therapies.
#
# **Key Example:** `glimepiride + insulin` vs `metformin`
# * **Mean Difference:** $-1.1369$ days
# * **Adjusted p-value:** $0.0$ (`reject = True`)
# * **Interpretation:** Patients on metformin alone are discharged **~1.14 days earlier** than those on more complex combination regimens.
#
# ### 2. The "Insulin Effect": Longer Hospitalization
#
# A consistent pattern emerges showing that the introduction or presence of insulin in a regimen is heavily tied to prolonged hospital stays:
#
# * **Example 1:** `glipizide` vs `glipizide + insulin`
#   * **Mean Difference:** $+0.7074$ days (`reject = True`)
#   * *Insight:* Adding insulin increases hospital stay by **~0.7 days**.
# * **Example 2:** `glyburide` vs `glyburide + insulin`
#   * **Mean Difference:** $+0.4981$ days (`reject = True`)
#   * *Insight:* Adding insulin increases stay by **~0.5 days**.
#
# #### Clinical Context & Justification
# This does **NOT** imply insulin is clinically harmful or inefficient. Rather, within hospital operations:
# * Insulin is typically prescribed for patients with **more severe, acute, or uncontrolled diabetic conditions**.
# * These patients naturally require a longer period of clinical monitoring, glucose titration, and stabilization before a safe discharge can be authorized.
#
# ### 3. Homogeneous Effect Among Insulin-Based Combinations
#
# When comparing different insulin-based combination regimens against one another, the differences completely fade away:
# * `glimepiride + insulin` vs `glipizide + insulin` $\rightarrow$ `p-adj = 0.9632` (`reject = False`)
# * `glimepiride + insulin` vs `glyburide + insulin` $\rightarrow$ `p-adj = 0.9998` (`reject = False`)
# * `glipizide + insulin` vs `glyburide + insulin` $\rightarrow$ `p-adj = 0.9997` (`reject = False`)
#
# #### Clinical Interpretation
# Once a patient's condition requires insulin, the specific choice of accompanying sulfonylurea (`glimepiride`, `glipizide`, or `glyburide`) **does not significantly affect** the hospital length of stay. All insulin-based oral combination regimens yield statistically equivalent operational outcomes.
#
# ---
#
# ### Summary Insight
#
# The Tukey HSD post-hoc analysis isolates three key clinical operational insights for the hospital dashboard:
#
# 1. **Metformin monotherapy is the most efficient regimen:** It reduces hospital stay by $0.31$ to $1.14$ days ($p < 0.001$).
# 2. **Insulin increases hospitalization burden:** It extends stay durations by $0.5$ to $0.7$ days ($p < 0.001$), reflecting disease severity and titration needs.
# 3. **Insulin-based oral combinations are statistically equivalent:** No meaningful operational differences exist among sulfonylurea + insulin regimens ($p > 0.05$).

# %%
plt.figure(figsize = (14,6))
order = df_top_regiment.groupby('regiment')['time_in_hospital'].mean().sort_values().index
order
# Out:
# Index(['metformin', 'glipizide', 'glyburide+metformin', 'glyburide', 'insulin',
#        'insulin+metformin', 'insulin+pioglitazone', 'glipizide+insulin',
#        'glyburide+insulin', 'glimepiride+insulin'],
#       dtype='object', name='regiment')

# %%
sns.barplot(
    x = 'regiment',
    y = 'time_in_hospital',
    data = df_top_regiment,
    order = order,
    palette = 'muted'
)
plt.title('Average time staying in hospital following top 10 regiments')
plt.xlabel('Regiments')
plt.ylabel('Average time (days)')
plt.xticks(rotation = 45, ha = 'right')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/0m/pfbtp6fn1zn7230dkmqp6vhh0000gn/T/ipykernel_82897/3884765323.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
